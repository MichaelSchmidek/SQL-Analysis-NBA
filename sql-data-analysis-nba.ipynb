# %% [markdown]
# ## Motivation

# %% [markdown]
# The below notebook is intended to be educational for those looking to learn the basics of SQL. It involves using SQL to perform data analysis on using a database containing information about the National Basketball Association (NBA). In the process, we will explore the data, utilize joins, perform basic analytics, and create visualizations of relevant trends.

# %% [markdown]
# ## Process

# %% [markdown]
# **Our analysis will adhere to the following 4 steps:**
#
# 1. Gain a high level understanding of the data at hand by looking at and briefly discussing relevant tables in the dataset.
# 2. Use joins to create new tables for analysis.
# 3. Perform simple analytics on our data using aggregation.
# 4. Visualize trends in our data using Plotly and Seaborn.

# %%
#Import packages

import numpy as np 
import pandas as pd 
import sqlite3
import matplotlib.pyplot as plt

path = "../input/basketball/" #Everything preceding the file name
database = path + 'basketball.sqlite' #The path + the file name

# %% [markdown]
# ## Overview of Data

# %% [markdown]
# Connect to the database and get a list of the tables within it.

# %%
# sqlite3.connect() Creates a connection object
# database is the variable we established above
conn = sqlite3.connect(database)

#pd.read_sql() is a retrieve function that retrieves what we put in the parenthesis

#After SELECT, put what you want to see. In this case we put *, which means see everything

#After FROM choose a source
    # sqlite_master is an internal table that is present in all SQLite databases. The content of this table describes the database's schema.
    
#After WHERE specify a condiction
    # condition here is where type = table
    
#End with a ";" and close the quotation marks

# conn is our connection object

tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#      type                   name               tbl_name  rootpage  \
# 0   table                 Player                 Player         2
# 1   table                   Team                   Team         4
# 2   table        Team_Attributes        Team_Attributes         5
# 3   table           Team_History           Team_History         6
# 4   table      Player_Attributes      Player_Attributes        15
# 5   table         Game_Officials         Game_Officials      8375
# 6   table  Game_Inactive_Players  Game_Inactive_Players      8997
# 7   table            Team_Salary            Team_Salary     13415
# 8   table          Player_Salary          Player_Salary     23558
# 9   table                  Draft                  Draft     23559
# 10  table          Draft_Combine          Draft_Combine     23562
# 11  table          Player_Photos          Player_Photos     23565
# 12  table            Player_Bios            Player_Bios     22541
# 13  table                   Game                   Game        25
# 14  table                   News                   News     13142
# 15  table           News_Missing           News_Missing    198017
#
#                                                   sql
# 0   CREATE TABLE "Player" (\n"id" TEXT,\n  "full_n...
# 1   CREATE TABLE "Team" (\n"id" TEXT,\n  "full_nam...
# 2   CREATE TABLE "Team_Attributes" (\n"ID" TEXT,\n...
# 3   CREATE TABLE "Team_History" (\n"ID" TEXT,\n  "...
# 4   CREATE TABLE "Player_Attributes" (\n"ID" TEXT,...
# 5   CREATE TABLE "Game_Officials" (\n"OFFICIAL_ID"...
# 6   CREATE TABLE "Game_Inactive_Players" (\n"PLAYE...
# 7   CREATE TABLE `Team_Salary` (\n  `nameTeam` TEX...
# 8   CREATE TABLE `Player_Salary` (\n  `slugSeason`...
# 9   CREATE TABLE `Draft` (\n  `yearDraft` REAL,\n ...
# 10  CREATE TABLE `Draft_Combine` (\n  `yearCombine...
# 11  CREATE TABLE `Player_Photos` (\n  `isActive` I...
# 12  CREATE TABLE `Player_Bios` (\n  `namePlayerBRE...
# 13  CREATE TABLE "Game" (\n"GAME_ID" TEXT,\n  "SEA...
# 14  CREATE TABLE "News" (\n"title" TEXT,\n  "autho...
# 15  CREATE TABLE "News_Missing" (\n"link" TEXT,\n ...

# %% [markdown]
# #### Look at Tables Individually to Plan Analysis
#
# Let's take a look at the following tables:
# 1. Player
# 3. Draft
# 4. Player_Bios
# 5. Player_Photos

# %%
# Look at active players in the Player table
    # 519 Players

Active_Player = pd.read_sql("""SELECT *
                        FROM Player
                        WHERE is_active=1; """, conn)


Active_Player
# Out:
#           id                 full_name first_name         last_name  is_active
# 0     203500              Steven Adams     Steven             Adams          1
# 1    1628389               Bam Adebayo        Bam           Adebayo          1
# 2     200746         LaMarcus Aldridge   LaMarcus          Aldridge          1
# 3    1629734            Kyle Alexander       Kyle         Alexander          1
# 4    1629638  Nickeil Alexander-Walker    Nickeil  Alexander-Walker          1
# ..       ...                       ...        ...               ...        ...
# 514   201152            Thaddeus Young   Thaddeus             Young          1
# 515  1629027                Trae Young       Trae             Young          1
# 516   203469               Cody Zeller       Cody            Zeller          1
# 517  1627790                Ante Zizic       Ante             Zizic          1
# 518  1627826               Ivica Zubac      Ivica             Zubac          1
#
# [519 rows x 5 columns]

# %%
# Look at draft table
    # Gives us relevant information about drafted players, such as the year they were drafted, the pick they were drafted with, and the team that drafted them
    
Draft = pd.read_sql("""SELECT *
                        FROM Draft ; """, conn)


Draft
# Out:
#       yearDraft  numberPickOverall  numberRound  numberRoundPick  \
# 0        2020.0                1.0          1.0              1.0
# 1        2020.0                2.0          1.0              2.0
# 2        2020.0                3.0          1.0              3.0
# 3        2020.0                4.0          1.0              4.0
# 4        2020.0                5.0          1.0              5.0
# ...         ...                ...          ...              ...
# 7885     1949.0                6.0          1.0              6.0
# 7886     1949.0                7.0          1.0              7.0
# 7887     1949.0                8.0          1.0              8.0
# 7888     1949.0                9.0          1.0              9.0
# 7889     1949.0               10.0          1.0             10.0
#
#             namePlayer slugTeam nameOrganizationFrom typeOrganizationFrom  \
# 0      Anthony Edwards      MIN              Georgia   College/University
# 1        James Wiseman      GSW              Memphis   College/University
# 2          LaMelo Ball      CHA            Illawarra      Other Team/Club
# 3     Patrick Williams      CHI        Florida State   College/University
# 4          Isaac Okoro      CLE               Auburn   College/University
# ...                ...      ...                  ...                  ...
# 7885   Ron Livingstone      BAL              Wyoming   College/University
# 7886      Dick McGuire      NYK      St. John's (NY)   College/University
# 7887     Wallace Jones      WAS             Kentucky   College/University
# 7888       Jack Kerris      CHS       Loyola-Chicago   College/University
# 7889        Frank Saul      ROC           Seton Hall   College/University
#
#        idPlayer        idTeam                nameTeam      cityTeam  \
# 0     1630162.0  1.610613e+09  Minnesota Timberwolves     Minnesota
# 1     1630164.0  1.610613e+09   Golden State Warriors  Golden State
# 2     1630163.0  1.610613e+09       Charlotte Hornets     Charlotte
# 3     1630172.0  1.610613e+09           Chicago Bulls       Chicago
# 4     1630171.0  1.610613e+09     Cleveland Cavaliers     Cleveland
# ...         ...           ...                     ...           ...
# 7885    77392.0  1.610610e+09       Baltimore Bullets     Baltimore
# 7886    77537.0  1.610613e+09         New York Knicks      New York
# 7887    77199.0  1.610610e+09     Washington Capitols    Washington
# 7888    77249.0  1.610610e+09           Chicago Stags       Chicago
# 7889    78063.0  1.610613e+09        Rochester Royals     Rochester
#
#           teamName  PLAYER_PROFILE_FLAG slugOrganizationTypeFrom  \
# 0     Timberwolves                  1.0                      COL
# 1         Warriors                  1.0                      COL
# 2          Hornets                  1.0                      PRO
# 3            Bulls                  1.0                      COL
# 4        Cavaliers                  1.0                      COL
# ...            ...                  ...                      ...
# 7885       Bullets                  1.0                      COL
# 7886        Knicks                  1.0                      COL
# 7887      Capitols                  1.0                      COL
# 7888         Stags                  1.0                      COL
# 7889        Royals                  1.0                      COL
#
#      locationOrganizationFrom
# 0                        None
# 1                        None
# 2                   Australia
# 3                        None
# 4                        None
# ...                       ...
# 7885                     None
# 7886                     None
# 7887                     None
# 7888                     None
# 7889                     None
#
# [7890 rows x 16 columns]

# %%
# Look at Player_Attributes table
    # Contains physical and positional attributes of each player along with background information such as alma mater.
    
Attributes = pd.read_sql("""SELECT *
                        FROM Player_Attributes; """, conn)


Attributes
# Out:
#            ID FIRST_NAME     LAST_NAME   DISPLAY_FIRST_LAST  \
# 0       76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1       76002       Zaid    Abdul-Aziz      Zaid Abdul-Aziz
# 2       76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 3          51    Mahmoud    Abdul-Rauf   Mahmoud Abdul-Rauf
# 4        1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
# ...       ...        ...           ...                  ...
# 4495  1627790       Ante         Zizic           Ante Zizic
# 4496    78647        Jim          Zoet             Jim Zoet
# 4497    78648       Bill          Zopf            Bill Zopf
# 4498  1627826      Ivica         Zubac          Ivica Zubac
# 4499    78650       Matt         Zunic           Matt Zunic
#
#      DISPLAY_LAST_COMMA_FIRST  DISPLAY_FI_LAST          PLAYER_SLUG  \
# 0             Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1            Abdul-Aziz, Zaid    Z. Abdul-Aziz      zaid-abdul-aziz
# 2        Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 3         Abdul-Rauf, Mahmoud    M. Abdul-Rauf   mahmoud-abdul-rauf
# 4          Abdul-Wahad, Tariq   T. Abdul-Wahad    tariq-abdul-wahad
# ...                       ...              ...                  ...
# 4495              Zizic, Ante         A. Zizic           ante-zizic
# 4496                Zoet, Jim          J. Zoet             jim-zoet
# 4497               Zopf, Bill          B. Zopf            bill-zopf
# 4498             Zubac, Ivica         I. Zubac          ivica-zubac
# 4499              Zunic, Matt         M. Zunic           matt-zunic
#
#                 BIRTHDATE             SCHOOL  COUNTRY  ... NBA_FLAG  \
# 0     1968-06-24T00:00:00               Duke      USA  ...        Y
# 1     1946-04-07T00:00:00         Iowa State      USA  ...        Y
# 2     1947-04-16T00:00:00               UCLA      USA  ...        Y
# 3     1969-03-09T00:00:00    Louisiana State      USA  ...        Y
# 4     1974-11-03T00:00:00     San Jose State   France  ...        Y
# ...                   ...                ...      ...  ...      ...
# 4495  1997-01-04T00:00:00                     Croatia  ...        Y
# 4496  1953-12-30T00:00:00         Kent State      USA  ...        Y
# 4497  1948-06-07T00:00:00           Duquesne      USA  ...        Y
# 4498  1997-03-18T00:00:00        Mega Basket  Croatia  ...        Y
# 4499  1919-12-19T00:00:00  George Washington      USA  ...        Y
#
#       GAMES_PLAYED_FLAG  DRAFT_YEAR  DRAFT_ROUND DRAFT_NUMBER   PTS  AST  \
# 0                     Y        1990            1           25   5.7  0.3
# 1                     Y        1968            1            5   9.0  1.2
# 2                     Y        1969            1            1  24.6  3.6
# 3                     Y        1990            1            3  14.6  3.5
# 4                     Y        1997            1           11   7.8  1.1
# ...                 ...         ...          ...          ...   ...  ...
# 4495                  Y        2016            1           23   6.0  0.6
# 4496                  Y   Undrafted    Undrafted    Undrafted   0.3  0.1
# 4497                  Y        1970            2           33   2.2  1.4
# 4498                  Y        2016            2           32   8.5  1.1
# 4499                  Y        1947         None         None   4.9  0.9
#
#        REB ALL_STAR_APPEARANCES    PIE
# 0      3.3                  0.0    NaN
# 1      8.0                  0.0    NaN
# 2     11.2                 18.0    NaN
# 3      1.9                  0.0    NaN
# 4      3.3                  0.0    NaN
# ...    ...                  ...    ...
# 4495   3.9                  0.0    NaN
# 4496   1.1                  0.0    NaN
# 4497   0.9                  0.0    NaN
# 4498   7.0                  NaN  0.126
# 4499   NaN                  0.0    NaN
#
# [4500 rows x 37 columns]

# %%
# Look at Player_Photos table
    # Contains links to photos of the players
    
Photos = pd.read_sql("""SELECT *
                        FROM Player_Photos ; """, conn)


Photos
# Out:
#       isActive  isRookie           namePlayer   idPlayer  countSeasons  \
# 0            0         0       Alaa Abdelnaby    76001.0           4.0
# 1            0         0      Zaid Abdul-Aziz    76002.0           9.0
# 2            0         0  Kareem Abdul-Jabbar    76003.0          19.0
# 3            0         0   Mahmoud Abdul-Rauf       51.0          10.0
# 4            0         0    Tariq Abdul-Wahad     1505.0           6.0
# ...        ...       ...                  ...        ...           ...
# 4588         0         0           Ante Zizic  1627790.0           2.0
# 4589         0         0             Jim Zoet    78647.0           0.0
# 4590         0         0            Bill Zopf    78648.0           0.0
# 4591         1         0          Ivica Zubac  1627826.0           4.0
# 4592         0         0           Matt Zunic    78650.0           0.0
#
#       yearSeasonFirst  yearSeasonLast        idTeam  hasGamesPlayedFlag  \
# 0              1990.0          1994.0           NaN                   0
# 1              1968.0          1977.0           NaN                   0
# 2              1969.0          1988.0           NaN                   0
# 3              1990.0          2000.0           NaN                   0
# 4              1997.0          2003.0           NaN                   0
# ...               ...             ...           ...                 ...
# 4588           2017.0          2019.0           NaN                   0
# 4589           1982.0          1982.0           NaN                   0
# 4590           1970.0          1970.0           NaN                   0
# 4591           2016.0          2020.0  1.610613e+09                   0
# 4592           1948.0          1948.0           NaN                   0
#
#                             urlPlayerStats  \
# 0       https://stats.nba.com/player/76001
# 1       https://stats.nba.com/player/76002
# 2       https://stats.nba.com/player/76003
# 3          https://stats.nba.com/player/51
# 4        https://stats.nba.com/player/1505
# ...                                    ...
# 4588  https://stats.nba.com/player/1627790
# 4589    https://stats.nba.com/player/78647
# 4590    https://stats.nba.com/player/78648
# 4591  https://stats.nba.com/player/1627826
# 4592    https://stats.nba.com/player/78650
#
#                                      urlPlayerThumbnail  \
# 0     https://stats.nba.com/media/players/230x185/76...
# 1     https://stats.nba.com/media/players/230x185/76...
# 2     https://stats.nba.com/media/players/230x185/76...
# 3     https://stats.nba.com/media/players/230x185/51...
# 4     https://stats.nba.com/media/players/230x185/15...
# ...                                                 ...
# 4588  https://ak-static.cms.nba.com/wp-content/uploa...
# 4589  https://stats.nba.com/media/players/230x185/78...
# 4590  https://stats.nba.com/media/players/230x185/78...
# 4591  https://stats.nba.com/media/players/230x185/16...
# 4592  https://stats.nba.com/media/players/230x185/78...
#
#                                       urlPlayerHeadshot  \
# 0     https://ak-static.cms.nba.com/wp-content/uploa...
# 1     https://ak-static.cms.nba.com/wp-content/uploa...
# 2     https://ak-static.cms.nba.com/wp-content/uploa...
# 3     https://ak-static.cms.nba.com/wp-content/uploa...
# 4     https://ak-static.cms.nba.com/wp-content/uploa...
# ...                                                 ...
# 4588  https://ak-static.cms.nba.com/wp-content/uploa...
# 4589  https://ak-static.cms.nba.com/wp-content/uploa...
# 4590  https://ak-static.cms.nba.com/wp-content/uploa...
# 4591  https://ak-static.cms.nba.com/wp-content/uploa...
# 4592  https://ak-static.cms.nba.com/wp-content/uploa...
#
#                                    urlPlayerActionPhoto  hasHeadShot  \
# 0     https://stats.nba.com/media/players/700/76001.png          0.0
# 1     https://stats.nba.com/media/players/700/76002.png          0.0
# 2     https://stats.nba.com/media/players/700/76003.png          1.0
# 3        https://stats.nba.com/media/players/700/51.png          0.0
# 4      https://stats.nba.com/media/players/700/1505.png          0.0
# ...                                                 ...          ...
# 4588  https://stats.nba.com/media/players/700/162779...          1.0
# 4589  https://stats.nba.com/media/players/700/78647.png          0.0
# 4590  https://stats.nba.com/media/players/700/78648.png          0.0
# 4591  https://stats.nba.com/media/players/700/162782...          1.0
# 4592  https://stats.nba.com/media/players/700/78650.png          0.0
#
#       hasThumbnail  hasAction  \
# 0              1.0        1.0
# 1              1.0        1.0
# 2              1.0        1.0
# 3              1.0        1.0
# 4              1.0        1.0
# ...            ...        ...
# 4588           1.0        0.0
# 4589           1.0        1.0
# 4590           1.0        1.0
# 4591           1.0        1.0
# 4592           1.0        1.0
#
#                                          urlPlayerPhoto
# 0     https://stats.nba.com/media/players/230x185/76...
# 1     https://stats.nba.com/media/players/230x185/76...
# 2     https://ak-static.cms.nba.com/wp-content/uploa...
# 3     https://stats.nba.com/media/players/230x185/51...
# 4     https://stats.nba.com/media/players/230x185/15...
# ...                                                 ...
# 4588  https://ak-static.cms.nba.com/wp-content/uploa...
# 4589  https://stats.nba.com/media/players/230x185/78...
# 4590  https://stats.nba.com/media/players/230x185/78...
# 4591  https://ak-static.cms.nba.com/wp-content/uploa...
# 4592  https://stats.nba.com/media/players/230x185/78...
#
# [4593 rows x 17 columns]

# %% [markdown]
# ## Create Personalized Tables using Joins
#
# As we can see above, we have a number of tables that we can leverage to create useful joined table:
#
# 1. A table that shows information about when a players was drafted, such as what pick they were drafted with, which team drafted them, and the college they attended.
# 2. A table that contains player attributes.
# 3. A table that includes a photo for each player.
#
# Furthermore, each of the above tables has a "Player ID" column that we can use to join the tables on. This is essential because over the course of the NBA's history, there have inevitably been a number of players with the same name. Merging on "Player ID" rather than name helps us address that problem.
#
# **In the below analysis, we will leverage the "Player ID" column as in order to perform joins on the above 3 tables.**

# %% [markdown]
# **Table 1: Player ID, Full player name, pick that player was drafted with, and player height**

# %%
pick_height = pd.read_sql("""SELECT 
                        Player_Attributes.ID AS Player_ID,
                        Player_Attributes.DISPLAY_FIRST_LAST AS Full_Name,
                        Draft.numberPickOverall AS Pick_Number_Overall,
                        Player_Attributes.Height AS Height
                        FROM Player_Attributes
                        JOIN Draft ON Player_Attributes.ID = Draft.idPlayer
                        ;""", conn)
pick_height
# Out:
#      Player_ID            Full_Name  Pick_Number_Overall  Height
# 0        76001       Alaa Abdelnaby                 25.0    82.0
# 1        76002      Zaid Abdul-Aziz                  5.0    81.0
# 2        76003  Kareem Abdul-Jabbar                  1.0    86.0
# 3           51   Mahmoud Abdul-Rauf                  3.0    73.0
# 4         1505    Tariq Abdul-Wahad                 11.0    78.0
# ...        ...                  ...                  ...     ...
# 3309   1627757    Stephen Zimmerman                 41.0    84.0
# 3310   1627835          Paul Zipser                 48.0    80.0
# 3311   1627790           Ante Zizic                 23.0    82.0
# 3312     78648            Bill Zopf                 33.0    73.0
# 3313   1627826          Ivica Zubac                 32.0    84.0
#
# [3314 rows x 4 columns]

# %% [markdown]
# **Table 2: Player ID, full player name, year that player was drafted, player position, and a link to player headshot, isolated to players drafted after 2000 and sorted in descending order by draft year**

# %%
year_position_headshot = pd.read_sql("""SELECT 
                        Player_Attributes.ID AS Player_ID,
                        Player_Attributes.DISPLAY_FIRST_LAST AS Full_Name,
                        Draft.yearDraft AS Draft_Year,
                        Player_Attributes.Position AS Position,
                        Player_Photos.urlPlayerHeadshot AS Headshot
                        FROM Player_Attributes
                        JOIN Draft ON Player_Attributes.ID = Draft.idPlayer
                        LEFT JOIN Player_Photos on Player_Photos.idPlayer = Draft.idPlayer
                        WHERE Draft_Year > 2000
                        ORDER by Draft_Year DESC
                        ;""", conn)
year_position_headshot
# Out:
#     Player_ID                 Full_Name  Draft_Year        Position  \
# 0     1629638  Nickeil Alexander-Walker      2019.0           Guard
# 1     1629628                RJ Barrett      2019.0   Forward-Guard
# 2     1629647             Darius Bazley      2019.0   Forward-Guard
# 3     1629048              Goga Bitadze      2019.0  Center-Forward
# 4     1629626                   Bol Bol      2019.0  Center-Forward
# ..        ...                       ...         ...             ...
# 977      2244           Jeff Trepagnier      2001.0           Guard
# 978      2222            Gerald Wallace      2001.0         Forward
# 979      2248               Earl Watson      2001.0           Guard
# 980      2206              Rodney White      2001.0         Forward
# 981      2254               Loren Woods      2001.0          Center
#
#                                               Headshot
# 0    https://ak-static.cms.nba.com/wp-content/uploa...
# 1    https://ak-static.cms.nba.com/wp-content/uploa...
# 2    https://ak-static.cms.nba.com/wp-content/uploa...
# 3    https://ak-static.cms.nba.com/wp-content/uploa...
# 4    https://ak-static.cms.nba.com/wp-content/uploa...
# ..                                                 ...
# 977  https://ak-static.cms.nba.com/wp-content/uploa...
# 978  https://ak-static.cms.nba.com/wp-content/uploa...
# 979  https://ak-static.cms.nba.com/wp-content/uploa...
# 980  https://ak-static.cms.nba.com/wp-content/uploa...
# 981  https://ak-static.cms.nba.com/wp-content/uploa...
#
# [982 rows x 5 columns]

# %% [markdown]
# **Table 3: Player ID, full player name, player's draft year, player's previous organization, player birthdate, and a link to player stats, isolated to players drafted by the New York Knicks and sorted in ascending alphabetical order by previous organization name.**

# %%
Knicks_picks = pd.read_sql("""SELECT 
                        Player_Attributes.ID AS Player_ID,
                        Player_Attributes.DISPLAY_FIRST_LAST AS Full_Name,
                        Draft.yearDraft AS Draft_Year,
                        Draft.nameOrganizationFrom AS Previous_Organization,
                        Player_Attributes.BIRTHDATE AS Birthdate,
                        Player_Photos.urlPlayerStats as Stats
                        FROM Player_Attributes
                        JOIN Draft ON Player_Attributes.ID = Draft.idPlayer
                        LEFT JOIN Player_Photos on Player_Photos.idPlayer = Draft.idPlayer
                        WHERE Draft.idTeam = 1610612752
                        ORDER by Previous_Organization ASC;""", conn)
Knicks_picks
# Out:
#     Player_ID          Full_Name  Draft_Year Previous_Organization  \
# 0     1629011  Mitchell Robinson      2018.0                  None
# 1       78385        Bill Turner      1966.0                 Akron
# 2       76553        Larry Demic      1979.0               Arizona
# 3      101112      Channing Frye      2005.0               Arizona
# 4      201941        Jordan Hill      2009.0               Arizona
# ..        ...                ...         ...                   ...
# 157     77637          Ron Moore      1987.0   West Virginia State
# 158     78380        Jack Turner      1954.0      Western Kentucky
# 159     77868       Ralph Polson      1952.0             Whitworth
# 160    203921   Cleanthony Early      2014.0         Wichita State
# 161     78238    Dave Stallworth      1965.0         Wichita State
#
#                Birthdate                                 Stats
# 0    1998-04-01T00:00:00  https://stats.nba.com/player/1629011
# 1    1944-02-18T00:00:00    https://stats.nba.com/player/78385
# 2    1957-06-27T00:00:00    https://stats.nba.com/player/76553
# 3    1983-05-17T00:00:00   https://stats.nba.com/player/101112
# 4    1987-07-27T00:00:00   https://stats.nba.com/player/201941
# ..                   ...                                   ...
# 157  1962-01-16T00:00:00    https://stats.nba.com/player/77637
# 158  1930-06-29T00:00:00    https://stats.nba.com/player/78380
# 159  1929-10-26T00:00:00    https://stats.nba.com/player/77868
# 160  1991-04-17T00:00:00   https://stats.nba.com/player/203921
# 161  1941-12-20T00:00:00    https://stats.nba.com/player/78238
#
# [162 rows x 6 columns]

# %% [markdown]
# ## Performing Simple Analytics Using Aggregation

# %% [markdown]
# Above, we practiced using joins to create personalized tables of interest.
# Using aggregation, we can also perform basic analytics on the data in our database to draw insights.

# %% [markdown]
# **Aggregated Table 1:**
# 1. How many times has each team drafted a player (sorted in ascending order)?

# %%
Team_Picks = pd.read_sql("""SELECT 
                            Draft.nameTeam AS Team_Name,
                            COUNT(idPlayer) AS Number_of_Picks
                            FROM Draft
                            GROUP BY idTeam
                            ORDER BY Number_of_Picks ASC
                            Limit 10;""", conn)

Team_Picks
# Out:
#                  Team_Name  Number_of_Picks
# 0  Providence Steamrollers                9
# 1        St. Louis Bombers               10
# 2            Chicago Stags               13
# 3      Washington Capitols               15
# 4     New Orleans Pelicans               33
# 5   Indianapolis Olympians               36
# 6          Toronto Raptors               40
# 7        Memphis Grizzlies               47
# 8               Miami Heat               58
# 9        Charlotte Hornets               60

# %% [markdown]
# The Providence Steamrollers have drafted the least players (9), while the Atlanta Hawks have drafted the most players (514).

# %% [markdown]
# **Aggregated Table 2:**
# 1. Which 10 teams have the highest average salary for this season and the 5 seasons after (sorted in descending order)?
# 2. Left Join the top 10 highest salaried teams with the number of players the team has drafted in its history.**

# %%
Average_Salary = pd.read_sql("""SELECT 
                            Draft.nameTeam AS Team_Name,
                            Avg(Team_Salary.[X2020-21]+Team_Salary.[X2021-22]) AS Average_Salary,
                            COUNT(Draft.idPlayer) AS Number_of_Picks
                            FROM Team_Salary
                            LEFT JOIN Draft on Team_Salary.nameTeam = Draft.nameTeam
                            GROUP BY idTeam
                            ORDER BY Average_Salary DESC
                            Limit 10;""", conn)

Average_Salary
# Out:
#                 Team_Name  Average_Salary  Number_of_Picks
# 0           Brooklyn Nets     334836819.0               16
# 1   Golden State Warriors     330573807.0              230
# 2    Los Angeles Clippers     282898895.0               82
# 3         Milwaukee Bucks     278821035.0              267
# 4      Philadelphia 76ers     276561380.0              364
# 5               Utah Jazz     266446024.0              150
# 6          Boston Celtics     264110511.0              450
# 7  Portland Trail Blazers     262969420.0              273
# 8  Minnesota Timberwolves     261546043.0               77
# 9      Los Angeles Lakers     258321235.0              304

# %% [markdown]
# The Brooklyn Nets have both the highest average salary and the lowest number of players drafted.

# %% [markdown]
# **Aggregated Table 3:**
# 1. Which draft combine year had the highest average player height?
# 2. What were average wingspans per year?
# 3. How many centers were in that draft? This may be an indicator of player height because center is, historically, the tallest position.
# 4. Order these results in descending order by average height.

# %%
Height_Centers = pd.read_sql("""SELECT 
                            Draft_Combine.yearCombine as Combine_Year,
                            AVG(Draft_Combine.heightWOShoesInches) As Average_Height_Inches,
                            AVG(Draft_Combine.wingspanInches) As Average_Wingspan_Inches,
                            SUM(CASE WHEN Draft_Combine.slugPosition = 'C' OR 'PF-C' THEN 1 ELSE 0 END) AS Count_Centers
                            FROM Draft_Combine
                            GROUP BY Combine_Year
                            ORDER BY Average_Height_Inches DESC
                            ;""", conn)

Height_Centers
# Out:
#     Combine_Year  Average_Height_Inches  Average_Wingspan_Inches  \
# 0           2011              78.456731                83.576923
# 1           2002              78.330128                83.115385
# 2           2004              78.307692                82.836538
# 3           2013              77.971311                82.672131
# 4           2017              77.866071                82.839286
# 5           2018              77.686508                82.761905
# 6           2003              77.661585                81.984756
# 7           2020              77.653571                82.621429
# 8           2005              77.604430                82.398734
# 9           2014              77.471774                82.087302
# 10          2008              77.440789                82.269737
# 11          2001              77.438462                81.023077
# 12          2006              77.406250                82.343750
# 13          2007              77.377632                82.421053
# 14          2009              77.305921                82.470395
# 15          2016              77.293103                82.698276
# 16          2012              77.287037                81.900000
# 17          2019              77.221014                82.514493
# 18          2015              77.191964                82.223214
# 19          2021              77.094444                82.016667
# 20          2010              76.989130                81.326087
#
#     Count_Centers
# 0               6
# 1              11
# 2               2
# 3               3
# 4               5
# 5               6
# 6               5
# 7               8
# 8               5
# 9               8
# 10              8
# 11              4
# 12              2
# 13              4
# 14              7
# 15              3
# 16              0
# 17              7
# 18              0
# 19              4
# 20              2

# %% [markdown]
# So there does not seem to be a positive correlation between number of centers and average height by combine. However, there is, unsurprisingly, a clear correlation betwen average height and average wingspan by combine.

# %% [markdown]
# ## Visualizing Trends in our data

# %% [markdown]
# **Visualization 1**
# Top 10 Highest Paying NBA Teams by Average Salary (2020-26) using Plotly.

# %%
import plotly.express as px
fig = px.bar(Average_Salary, x= 'Team_Name', y= 'Average_Salary', 
             title="Top 10 Highest Paying NBA Teams by Average Salary (2020-26)",
             labels=dict(Team_Name="Team Name", Average_Salary= "Average Salary" ))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="3a7361d1-c645-4060-ba66-b6d8869f4b5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a7361d1-c645-4060-ba66-b6d8869f4b5b")) {                    Plotly.newPlot(                        "3a7361d1-c645-4060-ba66-b6d8869f4b5b",                        [{"alignmentgroup":"True","hovertemplate":"Team Name=%{x}<br>Average Salary=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Brooklyn Nets","Golden State Warriors","Los Angeles Clippers","Milwaukee Bucks","Philadelphia 76ers","Utah Jazz","Boston Celtics","Portland Trail Blazers","Minnesota Timberwolves","Los Angeles Lakers"],"xaxis":"x","y":[334836819.0,330573807.0,282898895.0,278821035.0,276561380.0,266446024.0,264110511.0,262969420.0,261546043.0,258321235.0],"yaxis":"y"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}], ...

# %% [markdown]
# **Visualization 2**
# Histplot visualization of the number of players at each height using Seaborn.

# %%
import seaborn as sns
sns.histplot(pick_height.Height, kde=True, binwidth = 2, bins = 30).set_title('Count of Players by Height')
# Out:
# Text(0.5, 1.0, 'Count of Players by Height')

# %% [markdown]
# **Visualization 3**
# Scatterplot visualization of the correlation between height and wingspan for draft combine player using Plotly.

# %%
Height_Wingspan = pd.read_sql("""SELECT 
                            Draft_Combine.heightWOShoesInches,
                            Draft_Combine.wingspanInches
                            FROM Draft_Combine
                            ;""", conn)

px.scatter(Height_Wingspan, y="heightWOShoesInches", x="wingspanInches",
           title="Correlation Between Height and Wingspan for Draft Combine Players",
           labels=dict(heightWOShoesInches="Height (Without Shoes) in Inches", wingspanInches= "Wingspan in Inches" ))
# Out:
# <div>                            <div id="d51d41f3-97bd-4797-9710-17ce99af1677" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d51d41f3-97bd-4797-9710-17ce99af1677")) {                    Plotly.newPlot(                        "d51d41f3-97bd-4797-9710-17ce99af1677",                        [{"hovertemplate":"Wingspan in Inches=%{x}<br>Height (Without Shoes) in Inches=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergl","x":[86.5,80.5,87.5,84.0,86.0,85.25,72.0,83.0,76.0,79.0,82.0,86.0,73.5,82.5,80.5,76.0,82.0,84.5,81.5,75.75,83.0,78.0,84.5,80.0,78.25,83.0,70.0,75.5,80.0,83.0,81.0,80.5,85.0,80.0,83.25,80.0,76.5,84.5,85.5,81.5,82.5,84.5,87.5,83.5,82.5,81.5,80.5,77.25,81.25,81.0,81.5,77.5,80.0,75.75,75.5,75.0,81.0,87.0,83.0,80.5,86.5,81.25,78.5,74.5,90.0,84.5,81.5,81.5,82.5,80.5,79.5,88.0,83.5,85.5,80.75,85.0,83.75,76.0,80.25,87.0,88.0,86.75,83.5,87.0,88.5,77.5,90.5,83.75,90.5,86.5,80.0,83.5,90.0,82.75,82.5,78.5,73.25,78.25,83.25,87.0,80.0,84.25,86.0,90.5,81.25,88.0,83.75,82.75,84.0,77.25,89.0,88.0,81.0,78.75,81.25,75.5,84.5,80.25,83.5,83.0,85.5,86.5,73.5,74.75,80.0,83.5,76.5,82.5,76.5,81.75,89.75,84.25,81.5,84.5,85.75,79.5,83.25,89.0,78.75,83.5,89.5,85.5,83.5,88.5,83.75,76.0,81.0,84.0,85.5,85.75,86.25,86.5,74.25,79.0,88.5,83.5,83.5,84.0,78.0,87.5,85.0,78.25,81.0,70.75,82.75,82.25,88.0,86.5,84.5,84.5,79.0,73.0,84.0,79.75,84.0,78.0,75.75,83.0,73.0,85.0,84.0,84.5,91.0,86.25,84.0,83.5,74.5,83.75,86.0,71.75,86.0,77.0,84.5,84.0,78.5,82.0,85.5,82.25,79.5,89.5,83.5,74.5,82.0,79.0,85.0,82.5,81.75,82.0,82.25,79.0,83.5,81.75,80.5,83.5,85.0,85.75,76.5,77.75,74.0,85.0,80.0,75.5,84.5,82.0,84.5,86.5,83.0,84.0,84.5,77.0,78.0,81.25,80.75,87.5,76.0,86.25,78.5,85.5,86.0,81.25,82.0,84.0,79.25,80.25,77.25,82.5,88.0,71.5,73.0,79.25,83.0,78.5,85.0,78.25,78.0,87.25,82.75,86.0,86.75,85.0,82.75,84.0,84.25,82.75,81.0,86.5,83.75,78.5,84.5,77.5,78.0,81.5,90.25,87.0,92.0,85.0,87.5,89.0,85.0,87.75,87.0,75.5,86.0,77.25,89.75,85.0,76.5,75.0,82.0,82.0,82.25,86.5,87.5,85.0,77.5,82.75,86.0,80.5,88.25,77.5,87.0,91.5,81.0,81.0,86.0,73.0,86.5,null,79.0,82.0,81.0,83.0,78.5,85.5,73.5,87.0,83.0,81.5,83.0,84.5,88.0,78.5,88.5,81.0,80.5,79.5,85.0,85.0,86.0,80.5,79.5,88.5,84.5,84.5,83.0,89.0,80.5,86.5,87.0,74.5,85.5,84.0,83.0,81.5,84.5,84.0,86.0,79.0,81.0,84.5,83.5,74.5,82.0,88.0,82.5,79.0,83.5,81.5,78.5,79.5,71.5,89.5,84.5,81.5,82.0,73.0,83.5,83.0,83.0,84.0,82.0,81.0,86.0,86.0,null,83.0,79.0,76.5,84.0,78.0,84.0,83.5,85.5,82.0,84.0,87.0,null,83.0,81.5,83.25,85.0,82.25,85.5,87.0,74.0,75.5,90.0,75.0,83.5,71.75,87.5,71.5,74.75,76.25,79.5,90.0,90.75,85.5,86.5,88.5,82.75,81.25,87.5,80.0,85.5,81.75,82.0,77.25,84.5,85.25,85.25,79.5,86.75,83.0,82.0,77.5,81.0,84.0,84.0,72.0,85.0,87.25,85.25,82.75,81.0,84.0,75.5,81.75,78.0,83.75,76.25,82.5,83.5,82.75,77.5,74.75,83.25,89.0,84.0,79.5,87.5,85.75,75.0,80.0,81.75,85.5,84.25,86.0,83.0,86.0,78.25,85.25,87.5,82.0,80.75,82.25,79.75,88.75,82.0,83.5,79.0,88.0,84.25,85.0,82.0,78.0,83.5,83.25,81.5,84.0,81.0,82.0,74.5,82.0,78.75,84.0,76.5,75.0,78.25,85.0,87.0,82.0,84.75,78.25,84.25,85.5,85.0,79.0,88.75,81.5,81.25,87.0,78.75,78.25,77.75,72.75,84.0,84.0,85.5,78.5,82.0,88.25,81.5,81.5,89.75,79.5,77.0,80.5,75.25,86.5,80.0,80.75,92.5,88.25,83.5,81.5,84.5,88.25,86.25,77.0,87.0,78.5,84.75,76.0,78.0,85.5,88.25,87.0,88.25,79.0,82.0,81.0,86.0,85.5,80.25,76.0,76.0,80.5,86.0,77.75,80.25,85.25,77.5,88.0,80.75,82.0,79.0,88.75,83.5,87.25,85.25,74.25,83.75,84.5,79.0,86.25,84.75,83.25,87.0,80.25,90.0,74.0,77.0,84.0,72.0,83.0,82.5,83.0,86.0,78.5,85.0,78.5,82.0,82.5,85.0,83.0,80.0,84.25,85.25,88.25,83.75,75.25,88.5,80.0,81.0,80.75,76.25,77.5,82.75,78.5,79.25,81.5,81.0,74.5,82.0,85.0,86.5,88.0,83.0,87.0,88.0,72.75,86.25,87.75,85.0,null,83 ...

# %% [markdown]
# ## Review

# %% [markdown]
# In this notebook, we:
#
# 1. Connected to the database
# 2. Learned about our data in order to plan our analysis
# 3. Used joins to create personalized tables
# 4. Performed simple analytics on our data
# 5. Visualized trends within our data.
#
# Hopefully this served as a useful introduction to SQL analysis. Thanks for reading!
